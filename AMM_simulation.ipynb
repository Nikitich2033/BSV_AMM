# %% [markdown]
# ## Code utilised in the experimentation chapter to simulate the operations of the devised AMM

# %%
import ccxt
import pandas as pd
import matplotlib.pyplot as plt

# Function to fetch level 2 order book data
def fetch_order_book(exchange_id, symbol, limit=10):
    exchange_class = getattr(ccxt, exchange_id)
    exchange = exchange_class()
    order_book = exchange.fetch_order_book(symbol, limit)
    return order_book

# Function to display basic analytics
def display_analytics(order_book):
    bids = order_book['bids']
    asks = order_book['asks']
    
    bid_prices = [bid[0] for bid in bids]
    bid_sizes = [bid[1] for bid in bids]
    ask_prices = [ask[0] for ask in asks]
    ask_sizes = [ask[1] for ask in asks]

    bid_df = pd.DataFrame(bids, columns=['Price', 'Size'])
    ask_df = pd.DataFrame(asks, columns=['Price', 'Size'])
    
    # Display dataframes
    print("Top Bids:")
    print(bid_df)
    print("\nTop Asks:")
    print(ask_df)
    
    # Plot order book depth 
    plt.figure(figsize=(12, 8))  
    plt.plot(bid_prices, bid_sizes, color='green', label='Bids', linewidth=2)
    plt.plot(ask_prices, ask_sizes, color='red', label='Asks', linewidth=2)
    plt.fill_between(bid_prices, bid_sizes, color='green', alpha=0.5)
    plt.fill_between(ask_prices, ask_sizes, color='red', alpha=0.5)
    
    plt.xlabel('Price', fontsize=16)  
    plt.ylabel('Size', fontsize=16) 
    plt.title('Order Book Depth', fontsize=20)  
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)  
    plt.grid(True) 
    plt.show()
    
# Main function
def main():
    exchange_id = 'okx'
    symbol = 'BSV/USDT'
    order_book = fetch_order_book(exchange_id, symbol)
    display_analytics(order_book)

if __name__ == "__main__":
    main()
# Out:
# Top Bids:
#    Price        Size
# 0  39.99    4.200000
# 1  39.98   17.697167
# 2  39.97   13.290005
# 3  39.96   47.828142
# 4  39.95   41.660152
# 5  39.94   27.628426
# 6  39.93   20.100000
# 7  39.92  103.982831
# 8  39.91   39.925508
# 9  39.90   53.737729
#
# Top Asks:
#    Price       Size
# 0  40.01   4.200000
# 1  40.02   7.683909
# 2  40.03  26.718611
# 3  40.04  23.853138
# 4  40.05  33.961452
# 5  40.06  44.393797
# 6  40.07  25.814621
# 7  40.08  40.172998
# 8  40.09  65.027890
# 9  40.10  36.897375

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Function to read trade data from CSV
def read_trade_data(file_path):
    df = pd.read_csv(file_path, header=None)
    return df

# Function to plot cumulative buys and sells within a specific trade range
def plot_cumulative_trades(trades, start, end):
    # Filter the range of trades
    trades = trades.iloc[start:end].copy()
    
    # Calculate cumulative buys and sells
    trades.loc[:, 'cumulative_buys'] = (trades[5] == 1).cumsum()
    trades.loc[:, 'cumulative_sells'] = (trades[5] == -1).cumsum()

    # Plot cumulative buys and sells
    plt.figure(figsize=(12, 6))
    plt.plot(trades.index, trades['cumulative_buys'], label='Cumulative Buys', color='green')
    plt.plot(trades.index, trades['cumulative_sells'], label='Cumulative Sells', color='red')
    plt.xlabel('Trade Number', fontsize=14, color='black')
    plt.ylabel('Cumulative Count', fontsize=14, color='black')
    plt.title(f'Cumulative Buys and Sells from Trade {start} to {end}', fontsize=16, color='black')
    plt.legend(fontsize=12)
    plt.tick_params(axis='x', labelsize=12, color='black')
    plt.tick_params(axis='y', labelsize=12, color='black')
    plt.grid(True)  # Add grid lines for better readability
    plt.tight_layout()
    plt.show()

# Main function
def main():
    file_path = 'Market_Execution_Data/ALCD_stream_800002.csv'
    trades = read_trade_data(file_path)
    
    # Plot only trades from 59,900 to 60,000
    plot_cumulative_trades(trades, 59900, 60000)

if __name__ == "__main__":
    main()

# %%
import ccxt
import pandas as pd
import mplfinance as mpf
from datetime import datetime, timedelta

# Function to fetch OHLCV data for a specific time range
def fetch_ohlcv(exchange, symbol, start_time, end_time, timeframe='1m'):
    since = exchange.parse8601(start_time.strftime('%Y-%m-%dT%H:%M:%SZ'))
    end = exchange.parse8601(end_time.strftime('%Y-%m-%dT%H:%M:%SZ'))
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, since=since)
    
    # Filter data to include only the timeframe between start_time and end_time
    df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.set_index('timestamp', inplace=True)
    df = df[(df.index >= start_time) & (df.index <= end_time)]
    
    return df

# Function to fetch recent trades
def fetch_recent_trades(exchange, symbol, start_time, end_time):
    since = exchange.parse8601(start_time.strftime('%Y-%m-%dT%H:%M:%SZ'))
    trades = exchange.fetch_trades(symbol, since=since)
    
    # Filter trades to include only the timeframe between start_time and end_time
    filtered_trades = [trade for trade in trades if start_time <= datetime.utcfromtimestamp(trade['timestamp'] / 1000) <= end_time]
    
    return filtered_trades

# Function to calculate trade statistics
def calculate_trade_stats(trades):
    total_trades = len(trades)
    total_bought_usd = sum(trade['price'] * trade['amount'] for trade in trades if trade['side'] == 'buy')
    total_sold_usd = sum(trade['price'] * trade['amount'] for trade in trades if trade['side'] == 'sell')
    total_bought_crypto = sum(trade['amount'] for trade in trades if trade['side'] == 'buy')
    total_sold_crypto = sum(trade['amount'] for trade in trades if trade['side'] == 'sell')

    return total_trades, total_bought_usd, total_sold_usd, total_bought_crypto, total_sold_crypto

# Function to calculate XAUT/BSV from XAUT/USDT and BSV/USDT
def calculate_xaut_bsv(xaut_usdt, bsv_usdt):
    xaut_bsv = xaut_usdt[['open', 'high', 'low', 'close']].div(bsv_usdt[['open', 'high', 'low', 'close']].values)
    xaut_bsv['volume'] = xaut_usdt['volume']  # Optionally adjust this to reflect XAUT/BSV trades
    return xaut_bsv

# Function to plot candlestick charts with trade stats
def plot_candlestick_chart(df, title, stats):
    mpf.plot(df, type='candle', style='charles', title=title, ylabel='Price', volume=True)
    
    print(f"{title} - Specified Time Frame")
    print(f"Number of trades: {stats[0]}")
    print(f"Total bought: {stats[1]:.2f} USD / {stats[3]:.4f} units")
    print(f"Total sold: {stats[2]:.2f} USD / {stats[4]:.4f} units\n")

def main():
    exchange_id = 'okx'
    exchange_class = getattr(ccxt, exchange_id)
    exchange = exchange_class()

    # Define the start and end time for the data fetch
    start_time = datetime(2024, 8, 13, 16, 45)
    end_time = datetime(2024, 8, 13, 18, 30)

    # Fetch data for BSV/USDT and XAUT/USDT
    bsv_usdt = fetch_ohlcv(exchange, 'BSV/USDT', start_time, end_time)
    xaut_usdt = fetch_ohlcv(exchange, 'XAUT/USDT', start_time, end_time)

    # Calculate XAUT/BSV
    xaut_bsv = calculate_xaut_bsv(xaut_usdt, bsv_usdt)

    # Fetch recent trades for the specified time frame
    bsv_usdt_trades = fetch_recent_trades(exchange, 'BSV/USDT', start_time, end_time)
    xaut_usdt_trades = fetch_recent_trades(exchange, 'XAUT/USDT', start_time, end_time)

    # Calculate trade stats
    bsv_usdt_stats = calculate_trade_stats(bsv_usdt_trades)
    xaut_usdt_stats = calculate_trade_stats(xaut_usdt_trades)

    # Plot each pair with trade stats
    plot_candlestick_chart(bsv_usdt, 'BSV/USDT Candlestick Chart', bsv_usdt_stats)
    plot_candlestick_chart(xaut_usdt, 'XAUT/USDT Candlestick Chart', xaut_usdt_stats)
    
    # Calculate and print the combined trades for XAUT/BSV
    xaut_bsv_stats = (bsv_usdt_stats[0] + xaut_usdt_stats[0], 
                      xaut_usdt_stats[1] / bsv_usdt['close'][-1], 
                      xaut_usdt_stats[2] / bsv_usdt['close'][-1], 
                      xaut_usdt_stats[3], 
                      xaut_usdt_stats[4])
    
    plot_candlestick_chart(xaut_bsv, 'XAUT/BSV Derived Candlestick Chart', xaut_bsv_stats)

if __name__ == "__main__":
    main()
# Out:
# BSV/USDT Candlestick Chart - Specified Time Frame
# Number of trades: 0
# Total bought: 0.00 USD / 0.0000 units
# Total sold: 0.00 USD / 0.0000 units
# XAUT/USDT Candlestick Chart - Specified Time Frame
# Number of trades: 0
# Total bought: 0.00 USD / 0.0000 units
# Total sold: 0.00 USD / 0.0000 units
# C:\Users\lyakh\AppData\Local\Temp\ipykernel_34284\4135849822.py:85: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   xaut_usdt_stats[1] / bsv_usdt['close'][-1],
# C:\Users\lyakh\AppData\Local\Temp\ipykernel_34284\4135849822.py:86: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   xaut_usdt_stats[2] / bsv_usdt['close'][-1],
# XAUT/BSV Derived Candlestick Chart - Specified Time Frame
# Number of trades: 0
# Total bought: 0.00 USD / 0.0000 units
# Total sold: 0.00 USD / 0.0000 units

# %%
import ccxt

# Function to fetch the order book
def fetch_order_book(exchange_id, symbol, limit=50):
    exchange_class = getattr(ccxt, exchange_id)
    exchange = exchange_class()
    order_book = exchange.fetch_order_book(symbol, limit=limit)
    return order_book

# Function to combine order books for XAUT/BSV
def combine_order_books(xaut_usdt, bsv_usdt):
    xaut_bsv_bids = []
    xaut_bsv_asks = []

    # Combine bids
    for price_usdt, size in xaut_usdt['bids']:
        bsv_price = price_usdt / bsv_usdt['asks'][0][0]
        xaut_bsv_bids.append([bsv_price, size])

    # Combine asks
    for price_usdt, size in xaut_usdt['asks']:
        bsv_price = price_usdt / bsv_usdt['bids'][0][0]
        xaut_bsv_asks.append([bsv_price, size])

    xaut_bsv_bids = sorted(xaut_bsv_bids, key=lambda x: x[0], reverse=True)
    xaut_bsv_asks = sorted(xaut_bsv_asks, key=lambda x: x[0])

    return {
        'bids': xaut_bsv_bids,
        'asks': xaut_bsv_asks
    }

# Function to print the top 50 orders
def print_top_orders(order_book, symbol):
    print(f"Top 50 orders for {symbol}:\n")
    
    print("Bids:")
    for i, order in enumerate(order_book['bids'][:50]):
        print(f"{i + 1}: Price: {order[0]:.8f} BSV, Size: {order[1]:.8f} XAUT")
    
    print("\nAsks:")
    for i, order in enumerate(order_book['asks'][:50]):
        print(f"{i + 1}: Price: {order[0]:.8f} BSV, Size: {order[1]:.8f} XAUT")

# Main function
def main():
    exchange_id = 'okx'
    
    # Fetch order books for XAUT/USDT and BSV/USDT
    xaut_usdt = fetch_order_book(exchange_id, 'XAUT/USDT')
    bsv_usdt = fetch_order_book(exchange_id, 'BSV/USDT')

    # Combine order books to create XAUT/BSV
    xaut_bsv = combine_order_books(xaut_usdt, bsv_usdt)

    # Print the top 50 orders for XAUT/BSV
    print_top_orders(xaut_bsv, 'XAUT/BSV')

if __name__ == "__main__":
    main()
# Out:
# Top 50 orders for XAUT/BSV:
#
# Bids:
# 1: Price: 62.50937266 BSV, Size: 0.52515200 XAUT
# 2: Price: 62.50687328 BSV, Size: 0.02895000 XAUT
# 3: Price: 62.48687828 BSV, Size: 0.04074900 XAUT
# 4: Price: 62.48437891 BSV, Size: 0.04280700 XAUT
# 5: Price: 62.46688328 BSV, Size: 2.50000000 XAUT
# 6: Price: 62.46438390 BSV, Size: 7.07431300 XAUT
# 7: Price: 62.43189203 BSV, Size: 10.61316200 XAUT
# 8: Price: 62.40189953 BSV, Size: 0.00395400 XAUT
# 9: Price: 62.39690077 BSV, Size: 17.14877200 XAUT
# 10: Price: 62.36440890 BSV, Size: 0.00122000 XAUT
# 11: Price: 62.35941015 BSV, Size: 0.00400800 XAUT
# 12: Price: 62.32691827 BSV, Size: 24.76494900 XAUT
# 13: Price: 62.30442389 BSV, Size: 5.00000000 XAUT
# 14: Price: 62.25943514 BSV, Size: 0.01605700 XAUT
# 15: Price: 62.23444139 BSV, Size: 2.02008000 XAUT
# 16: Price: 62.23194201 BSV, Size: 0.00436100 XAUT
# 17: Price: 62.22444389 BSV, Size: 31.86082600 XAUT
# 18: Price: 62.19195201 BSV, Size: 0.00122000 XAUT
# 19: Price: 62.18445389 BSV, Size: 0.05027600 XAUT
# 20: Price: 62.17945514 BSV, Size: 6.00000000 XAUT
# 21: Price: 62.12196951 BSV, Size: 38.91254000 XAUT
# 22: Price: 62.09947513 BSV, Size: 0.02334300 XAUT
# 23: Price: 62.06448388 BSV, Size: 0.00481000 XAUT
# 24: Price: 62.04698825 BSV, Size: 0.00241900 XAUT
# 25: Price: 62.01949513 BSV, Size: 0.00122000 XAUT
# 26: Price: 62.00949763 BSV, Size: 3.55000000 XAUT
# 27: Price: 61.98450387 BSV, Size: 0.13306300 XAUT
# 28: Price: 61.97200700 BSV, Size: 0.02339100 XAUT
# 29: Price: 61.94451387 BSV, Size: 0.00932900 XAUT
# 30: Price: 61.94201450 BSV, Size: 0.00144900 XAUT
# 31: Price: 61.93451637 BSV, Size: 0.03188000 XAUT
# 32: Price: 61.92201950 BSV, Size: 0.00100000 XAUT
# 33: Price: 61.91952012 BSV, Size: 45.98755000 XAUT
# 34: Price: 61.89452637 BSV, Size: 0.00530500 XAUT
# 35: Price: 61.85953512 BSV, Size: 0.50997200 XAUT
# 36: Price: 61.85453637 BSV, Size: 0.00246100 XAUT
# 37: Price: 61.84703824 BSV, Size: 0.02465900 XAUT
# 38: Price: 61.84453887 BSV, Size: 0.00606100 XAUT
# 39: Price: 61.80704824 BSV, Size: 0.03594000 XAUT
# 40: Price: 61.79205199 BSV, Size: 0.02426800 XAUT
# 41: Price: 61.78455386 BSV, Size: 0.02022600 XAUT
# 42: Price: 61.76455886 BSV, Size: 0.00241900 XAUT
# 43: Price: 61.75706073 BSV, Size: 0.04685000 XAUT
# 44: Price: 61.73456636 BSV, Size: 0.10121400 XAUT
# 45: Price: 61.73206698 BSV, Size: 0.26459600 XAUT
# 46: Price: 61.72706823 BSV, Size: 0.00585200 XAUT
# 47: Price: 61.71957011 BSV, Size: 0.02348700 XAUT
# 48: Price: 61.71707073 BSV, Size: 21.22502000 XAUT
# 49: Price: 61.70457386 BSV, Size: 0.00246100 XAUT
# 50: Price: 61.67458135 BSV, Size: 0.00122000 XAUT
#
# Asks:
# 1: Price: 62.57314329 BSV, Size: 0.00194000 XAUT
# 2: Price: 62.59814954 BSV, Size: 0.12193200 XAUT
# 3: Price: 62.60065016 BSV, Size: 0.50000000 XAUT
# 4: Price: 62.60815204 BSV, Size: 0.01043300 XAUT
# 5: Price: 62.61065266 BSV, Size: 3.53835100 XAUT
# 6: Price: 62.62565641 BSV, Size: 0.06441800 XAUT
# 7: Price: 62.63815954 BSV, Size: 7.07673000 XAUT
# 8: Price: 62.66816704 BSV, Size: 0.00194000 XAUT
# 9: Price: 62.67316829 BSV, Size: 13.11515700 XAUT
# 10: Price: 62.70067517 BSV, Size: 0.22584700 XAUT
# 11: Price: 62.70567642 BSV, Size: 14.15363500 XAUT
# 12: Price: 62.74068517 BSV, Size: 3.08093200 XAUT
# 13: Price: 62.77069267 BSV, Size: 24.76939000 XAUT
# 14: Price: 62.80070018 BSV, Size: 0.00144700 XAUT
# 15: Price: 62.81570393 BSV, Size: 0.07282300 XAUT
# 16: Price: 62.83570893 BSV, Size: 5.00000000 XAUT
# 17: Price: 62.87321830 BSV, Size: 31.84636000 XAUT
# 18: Price: 62.91322831 BSV, Size: 0.00121800 XAUT
# 19: Price: 62.92073018 BSV, Size: 0.00241700 XAUT
# 20: Price: 62.92573143 BSV, Size: 0.01974900 XAUT
# 21: Price: 62.95823956 BSV, Size: 6.00000000 XAUT
# 22: Price: 62.97574394 BSV, Size: 38.92333000 XAUT
# 23: Price: 62.98074519 BSV, Size: 0.00634400 XAUT
# 24: Price: 63.01575394 BSV, Size: 0.00888100 XAUT
# 25: Price: 63.08577144 BSV, Size: 0.00121800 XAUT
# 26: Price: 63.10077519 BSV, Size: 0.16169600 XAUT
# 27: Price: 63.14078520 BSV, Size: 0.00484300 XAUT
# 28: Price: 63.17829457 BSV, Size: 46.00031000 XAUT
# 29: Price: 63.20330083 BSV, Size: 0.00241700 XAUT
# 30: Price: 63.21830458 BSV, Size: 0.00144800 XAUT
# 31: Price: 63.25581395 BSV, Size: 0.39925500 XAUT
# 32: Price: 63.25831458 BSV, Size: 0.00121800 XAUT
# 33: Price: 63.34083521 BSV, Size: 0.01210900 XAUT
# 34: Price: 63.36584146 BSV, Size: 0.20351700 XAUT
# 35: Price: 63.37084271 BSV, Size: 0.19828800 XAUT
# 36: Price: 63.38334584 BSV, Size: 21.23091000 XAUT
# 37: Price: 63.38834709 BSV, Size: 0.01861700 XAUT
# 38: Price: 63.39084771 BSV, Size: 0.01604100 XAUT
# 39: Price: 63.41085271 BSV, Size: 0.00241100 XAUT
# 40: Price: 63.41585396 BSV, Size: 0.00775200 XAUT
# 41: Price: 63.43085771 BSV, Size: 0.00121800 XAUT
# 42: Price: 63.48337084 BSV, Size: 0.00241600 XAUT
# 43: Price: 63.52338085 BSV, Size: 0.01817100 XAUT
# 44: Price: 63.53088272 BSV, Size: 0.00792000 XAUT
# 45: Price: 63.54088522 BSV, Size: 0.03935400 XAUT
# 46: Price: 63.60340085 BSV, Size: 0.01331800 XAUT
# 47: Price: 63.64091023 BSV, Size: 0.00392900 XAUT
# 48: Price: 63.67091773 BSV, Size: 0.21406100 XAUT
# 49: Price: 63.69092273 BSV, Size: 0.19041000 XAUT
# 50: Price: 63.76594149 BSV, Size: 0.00241600 XAUT

# %%
import ccxt
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates

# Function to fetch trade data from OKX starting from a specific time
def fetch_trade_data(exchange_id, symbol, start_time, timeframe='1m', limit=60):
    exchange_class = getattr(ccxt, exchange_id)
    exchange = exchange_class()

    # Convert start time to a Unix timestamp in milliseconds
    since = int(datetime.strptime(start_time, '%d/%m/%Y %H:%M').timestamp() * 1000)

    # Fetch the OHLCV data starting from the 'since' timestamp
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, since=since, limit=limit)
    
    return ohlcv

# Function to create XAUT/BSV pair using XAUT/USDT and BSV/USDT
def create_xaut_bsv_pair(xaut_usdt, bsv_usdt):
    xaut_bsv = []
    for i in range(min(len(xaut_usdt), len(bsv_usdt))):
        xaut_usdt_price = xaut_usdt[i][4]
        bsv_usdt_price = bsv_usdt[i][4]
        xaut_bsv_price = xaut_usdt_price / bsv_usdt_price
        xaut_bsv.append([xaut_usdt[i][0], xaut_bsv_price, xaut_usdt[i][5]])
    return xaut_bsv

# Function to plot AMM balance changes for XAUT and BSV in separate plots
def plot_amm_balances_separate(df):
    # Define the date format to include day, month, and year
    date_format = mdates.DateFormatter('%d-%m-%Y %H:%M')

    # Plot XAUT balance
    plt.figure(figsize=(12, 6))
    plt.ticklabel_format(useOffset=False)
    plt.plot(df['timestamp'], df['xaut_balance'], label='XAUT Balance', color='blue')
    plt.xlabel('Time', fontsize=14, color='black')
    plt.ylabel('XAUT Balance in Liquidity Pool (XAUT)', fontsize=14, color='black')
    plt.tick_params(axis='y', labelcolor='black', labelsize=12)
    plt.tick_params(axis='x', labelsize=12, color='black')
    plt.gca().xaxis.set_major_formatter(date_format)
    plt.gca().xaxis.set_tick_params(rotation=45)
    plt.gca().ticklabel_format(style='plain', axis='y')  # Ensure that the y-axis does not use scientific notation
    plt.title('XAUT Balance in Liquidity Pool During AMM Trading Activity', fontsize=16, color='black')
    plt.grid(True)  # Add grid lines
    plt.tight_layout()
    plt.show()

    # Plot BSV balance
    plt.figure(figsize=(12, 6))
    plt.ticklabel_format(useOffset=False)
    plt.plot(df['timestamp'], df['bsv_balance'], label='BSV Balance', color='orange')
    plt.xlabel('Time', fontsize=14, color='black')
    plt.ylabel('BSV Balance in Liquidity Pool (BSV)', fontsize=14, color='black')
    plt.tick_params(axis='y', labelcolor='black', labelsize=12)
    plt.tick_params(axis='x', labelsize=12, color='black')
    plt.gca().xaxis.set_major_formatter(date_format)
    plt.gca().xaxis.set_tick_params(rotation=45)
    plt.gca().ticklabel_format(style='plain', axis='y')  # Ensure that the y-axis does not use scientific notation
    plt.title('BSV Balance in Liquidity Pool During AMM Trading Activity', fontsize=16, color='black')
    plt.grid(True) 
    plt.tight_layout()
    plt.show()

# Function to plot XAUT/BSV price changes
def plot_price_changes(df, symbol):
    # Define the date format to include day, month, and year
    date_format = mdates.DateFormatter('%d-%m-%Y %H:%M')

    plt.figure(figsize=(12, 6))
    plt.plot(df['timestamp'], df['price'], label='XAUT/BSV Price', color='green')
    plt.xlabel('Time', fontsize=14, color='black')
    plt.ylabel('Price (BSV)', fontsize=14, color='black')
    plt.tick_params(axis='y', labelcolor='black', labelsize=12)
    plt.tick_params(axis='x', labelsize=12, color='black')
    plt.gca().xaxis.set_major_formatter(date_format)
    plt.gca().xaxis.set_tick_params(rotation=45)
    plt.title(f'XAUT/BSV Price Changes During AMM Trading Activity', fontsize=16, color='black')
    plt.legend()
    plt.grid(True)  # Add grid lines
    plt.tight_layout()
    plt.show()

def simulate_amm_trades(trades, orders, initial_xaut, initial_price, xaut_usdt, bsv_usdt):

    # Initialize the XAUT and BSV balances and the constant product k
    xaut_balance = initial_xaut
    bsv_balance = initial_xaut * initial_price
    k = xaut_balance * bsv_balance  # Constant product formula (k = x * y)

    balances = []
    prices = []

    total_trades = 0
    total_volume_bsv = 0
    total_volume_usd = 0
    largest_trade_usd = 0
    smallest_trade_usd = float('inf')

    for i in range(min(len(orders), len(trades))):
        timestamp, close_price, _ = trades[i]
        action = "Sold" if orders[i] == -1 else "Bought"
        volume_xaut = abs(trades[i][2])

        # Ensure the volume is at least 0.1 XAUT
        if volume_xaut == 0:
            volume_xaut = 0.1

        # Store the balances before the trade for calculations
        bsv_balance_before = bsv_balance
        xaut_balance_before = xaut_balance

        # Get the prices in USDT before the trade
        bsv_price_before = bsv_usdt[i][4]
        xaut_price_before = xaut_usdt[i][4]

        if orders[i] == -1:  # Sell XAUT for BSV
            xaut_balance += volume_xaut  # Increase XAUT balance
            bsv_balance = k / xaut_balance  # Recalculate BSV balance using constant product formula (y' = k / x')
            bsv_received = bsv_balance_before - bsv_balance  # BSV received from the trade
            cost_usd = bsv_received * bsv_price_before  # Convert BSV to USD based on BSV price in USD
        else:  # Buy XAUT with BSV
            bsv_spent = volume_xaut * close_price  # BSV spent to buy the specified amount of XAUT
            xaut_balance = k / (bsv_balance + bsv_spent)  # Recalculate XAUT balance using constant product formula (x' = k / y')
            bsv_balance += bsv_spent  # Increase BSV balance by the spent amount
            cost_usd = bsv_spent * bsv_price_before  # Convert BSV to USD based on BSV price in USD

        # Update the invariant k (for validation, k should remain consistent)
        k = xaut_balance * bsv_balance  # Constant product formula (k = x' * y')

        # Calculate the new price of XAUT/BSV
        new_price = bsv_balance / xaut_balance  # Price calculation based on new balances

        # Get the prices in USDT after the trade
        bsv_price_after = bsv_usdt[i + 1][4] if i + 1 < len(bsv_usdt) else bsv_price_before
        xaut_price_after = xaut_usdt[i + 1][4] if i + 1 < len(xaut_usdt) else xaut_price_before

        # Print the current state
        print(f"Trade {i + 1}:")
        print(f"Timestamp: {datetime.utcfromtimestamp(timestamp / 1000)}")
        print(f"Action: {action} {volume_xaut:.4f} XAUT")
        print(f"XAUT Balance: {xaut_balance:.4f}")
        print(f"BSV Balance: {bsv_balance:.4f}")
        print(f"XAUT/BSV Price: {new_price:.4f}")
        print(f"BSV Price Before Trade: {bsv_price_before:.4f} USDT")
        print(f"XAUT Price Before Trade: {xaut_price_before:.4f} USDT")
        print(f"BSV Price After Trade: {bsv_price_after:.4f} USDT")
        print(f"XAUT Price After Trade: {xaut_price_after:.4f} USDT")
        print(f"Cost in BSV: {bsv_received:.4f} BSV")
        print(f"Cost in USD: {cost_usd:.4f} USD\n")

        # Track trade statistics
        total_trades += 1
        total_volume_bsv += bsv_received
        total_volume_usd += cost_usd
        largest_trade_usd = max(largest_trade_usd, cost_usd)
        smallest_trade_usd = min(smallest_trade_usd, cost_usd)

        balances.append((timestamp, xaut_balance, bsv_balance))
        prices.append((timestamp, new_price))

    # After all trades are done, print trade statistics
    print("Trade Summary:")
    print(f"Total number of trades: {total_trades}")
    print(f"Total trade volume in BSV: {total_volume_bsv:.4f} BSV")
    print(f"Total trade volume in USD: {total_volume_usd:.4f} USD")
    print(f"Largest trade in USD: {largest_trade_usd:.4f} USD")
    print(f"Smallest trade in USD: {smallest_trade_usd:.4f} USD\n")

    return balances, prices


def calculate_lp_values(balances, bsv_to_usdt, xaut_to_usdt, lp_stakes):
    total_value_before_usd = 0
    total_value_after_usd = 0
    
    for lp, stake in lp_stakes.items():
        xaut_balance_initial = balances[0][1] * stake
        bsv_balance_initial = balances[0][2] * stake
        
        xaut_balance_final = balances[-1][1] * stake
        bsv_balance_final = balances[-1][2] * stake
        
        value_before_usd = (xaut_balance_initial * xaut_to_usdt) + (bsv_balance_initial * bsv_to_usdt)
        value_after_usd = (xaut_balance_final * xaut_to_usdt) + (bsv_balance_final * bsv_to_usdt)
        
        total_value_before_usd += value_before_usd
        total_value_after_usd += value_after_usd
    
    print(f"Total value of LPs' assets before 100 trades: {total_value_before_usd:.4f} USD")
    print(f"Total value of LPs' assets after 100 trades: {total_value_after_usd:.4f} USD")

def calculate_fees_and_positions(balances, orders, xaut_to_usdt, bsv_to_usdt, fee_rate=0.003):
    # Initial LP stakes
    lp_stakes = {
        "LP1": 0.60,  # 60%
        "LP2": 0.30,  # 30%
        "LP3": 0.10   # 10%
    }

    # Initial LP earnings in BSV
    lp_earnings_bsv = {
        "LP1": 0.0,
        "LP2": 0.0,
        "LP3": 0.0
    }

    # Initial LP balances based on their stakes
    lp_initial_balances = {
        "LP1": {"xaut": balances[0][1] * lp_stakes["LP1"], "bsv": balances[0][2] * lp_stakes["LP1"]},
        "LP2": {"xaut": balances[0][1] * lp_stakes["LP2"], "bsv": balances[0][2] * lp_stakes["LP2"]},
        "LP3": {"xaut": balances[0][1] * lp_stakes["LP3"], "bsv": balances[0][2] * lp_stakes["LP3"]}
    }

    # Print initial LP positions
    print("Initial LP Positions:")
    for lp, balance in lp_initial_balances.items():
        print(f"{lp} - XAUT: {balance['xaut']:.4f}, BSV: {balance['bsv']:.4f}")

    # Loop through each trade to calculate fees and update LP earnings
    for i in range(len(balances) - 1):
        bsv_balance_before = balances[i][2]
        bsv_balance_after = balances[i + 1][2]

        bsv_traded = abs(bsv_balance_after - bsv_balance_before)

        # Fees are always paid in BSV
        fee_bsv = bsv_traded * fee_rate
        if orders[i] == -1 or orders[i] == 1:  # Both buy and sell involve BSV
            for lp in lp_earnings_bsv:
                lp_earnings_bsv[lp] += fee_bsv * lp_stakes[lp]

    # Calculate final LP balances after 100 trades
    lp_final_balances = {
        "LP1": {"xaut": balances[-1][1] * lp_stakes["LP1"], "bsv": balances[-1][2] * lp_stakes["LP1"]},
        "LP2": {"xaut": balances[-1][1] * lp_stakes["LP2"], "bsv": balances[-1][2] * lp_stakes["LP2"]},
        "LP3": {"xaut": balances[-1][1] * lp_stakes["LP3"], "bsv": balances[-1][2] * lp_stakes["LP3"]}
    }

    # Print earnings and final positions for each LP
    print("\nLP Earnings and Final Positions After 100 Trades:")
    for lp in lp_earnings_bsv:
        earnings_usdt = lp_earnings_bsv[lp] * bsv_to_usdt
        print(f"{lp}:")
        print(f"  BSV Earned: {lp_earnings_bsv[lp]:.4f} BSV (~{earnings_usdt:.2f} USDT)")
        print(f"  Initial XAUT/BSV Ratio: {lp_initial_balances[lp]['xaut']:.4f} / {lp_initial_balances[lp]['bsv']:.4f}")
        print(f"  Final XAUT/BSV Ratio: {lp_final_balances[lp]['xaut']:.4f} / {lp_final_balances[lp]['bsv']:.4f}")
        print(f"  Total Earnings from Fees in USD: {earnings_usdt:.2f} USDT\n")

    # Calculate and print the total value of LPs' assets before and after the trades
    calculate_lp_values(balances, bsv_to_usdt, xaut_to_usdt, lp_stakes)

# Main function
def main():
    exchange_id = 'okx'
    xaut_usdt_symbol = 'XAUT/USDT'
    bsv_usdt_symbol = 'BSV/USDT'

    # Fetch trade data for XAUT/USDT and BSV/USDT starting from 13/08/2024 16:45
    start_time = '13/08/2024 17:45'
    xaut_usdt_data = fetch_trade_data(exchange_id, xaut_usdt_symbol, start_time, timeframe='1m', limit=100)
    bsv_usdt_data = fetch_trade_data(exchange_id, bsv_usdt_symbol, start_time, timeframe='1m', limit=100)

    # Create XAUT/BSV pair data
    xaut_bsv_data = create_xaut_bsv_pair(xaut_usdt_data, bsv_usdt_data)

    # Load order stream data and extract the relevant range
    order_stream = pd.read_csv('Market_Execution_Data/ALCD_stream_800002.csv', header=None)
    orders = order_stream.iloc[59900:60000, 5].values

    # Get the latest price from the last trade
    latest_trade = xaut_bsv_data[-1]
    latest_price = latest_trade[1]

    # Initial balances for the AMM
    initial_xaut = 100000
    initial_price = latest_price

    balances, prices = simulate_amm_trades(xaut_bsv_data[:100], orders, initial_xaut, initial_price, xaut_usdt_data, bsv_usdt_data)

    # Convert balances and prices to DataFrame
    df_balances = pd.DataFrame(balances, columns=['timestamp', 'xaut_balance', 'bsv_balance'])
    df_prices = pd.DataFrame(prices, columns=['timestamp', 'price'])

    # Convert timestamp to datetime
    df_balances['timestamp'] = pd.to_datetime(df_balances['timestamp'], unit='ms')
    df_prices['timestamp'] = pd.to_datetime(df_prices['timestamp'], unit='ms')

    # Plot the balances and price changes
    plot_amm_balances_separate(df_balances)
    plot_price_changes(df_prices, 'XAUT/BSV')

    # Example values for conversion rates based on the last fetched prices
    xaut_to_usdt = xaut_usdt_data[-1][4]
    bsv_to_usdt = bsv_usdt_data[-1][4]

    # Calculate and print liquidity provider earnings and asset values before and after trades
    calculate_fees_and_positions(balances, orders, xaut_to_usdt, bsv_to_usdt)

if __name__ == "__main__":
    main()
# Out:
# Trade 1:
# Timestamp: 2024-08-13 16:45:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 100000.1000
# BSV Balance: 5610310.2270
# XAUT/BSV Price: 56.1030
# BSV Price Before Trade: 43.4600 USDT
# XAUT Price Before Trade: 2467.3000 USDT
# BSV Price After Trade: 43.6200 USDT
# XAUT Price After Trade: 2467.3000 USDT
# Cost in BSV: 5.6103 BSV
# Cost in USD: 243.8241 USD
#
# Trade 2:
# Timestamp: 2024-08-13 16:46:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.9992
# BSV Balance: 5610315.8833
# XAUT/BSV Price: 56.1032
# BSV Price Before Trade: 43.6200 USDT
# XAUT Price Before Trade: 2467.3000 USDT
# BSV Price After Trade: 43.6100 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6103 BSV
# Cost in USD: 246.7300 USD
#
# Trade 3:
# Timestamp: 2024-08-13 16:47:00
# Action: Bought 0.0579 XAUT
# XAUT Balance: 99999.9407
# BSV Balance: 5610319.1621
# XAUT/BSV Price: 56.1032
# BSV Price Before Trade: 43.6100 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.5800 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6103 BSV
# Cost in USD: 142.9878 USD
#
# Trade 4:
# Timestamp: 2024-08-13 16:48:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.8397
# BSV Balance: 5610324.8331
# XAUT/BSV Price: 56.1033
# BSV Price Before Trade: 43.5800 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.8000 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6103 BSV
# Cost in USD: 247.1400 USD
#
# Trade 5:
# Timestamp: 2024-08-13 16:49:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.7391
# BSV Balance: 5610330.4755
# XAUT/BSV Price: 56.1035
# BSV Price Before Trade: 43.8000 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.8000 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6103 BSV
# Cost in USD: 247.1400 USD
#
# Trade 6:
# Timestamp: 2024-08-13 16:50:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.6385
# BSV Balance: 5610336.1180
# XAUT/BSV Price: 56.1036
# BSV Price Before Trade: 43.8000 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.7600 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6103 BSV
# Cost in USD: 247.1400 USD
#
# Trade 7:
# Timestamp: 2024-08-13 16:51:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.5378
# BSV Balance: 5610341.7656
# XAUT/BSV Price: 56.1037
# BSV Price Before Trade: 43.7600 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.7000 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6103 BSV
# Cost in USD: 247.1400 USD
#
# Trade 8:
# Timestamp: 2024-08-13 16:52:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.6378
# BSV Balance: 5610336.1553
# XAUT/BSV Price: 56.1036
# BSV Price Before Trade: 43.7000 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.7700 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 245.1728 USD
#
# Trade 9:
# Timestamp: 2024-08-13 16:53:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.5372
# BSV Balance: 5610341.8016
# XAUT/BSV Price: 56.1037
# BSV Price Before Trade: 43.7700 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.7500 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 10:
# Timestamp: 2024-08-13 16:54:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.6372
# BSV Balance: 5610336.1912
# XAUT/BSV Price: 56.1036
# BSV Price Before Trade: 43.7500 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.8600 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 245.4533 USD
#
# Trade 11:
# Timestamp: 2024-08-13 16:55:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.5368
# BSV Balance: 5610341.8260
# XAUT/BSV Price: 56.1037
# BSV Price Before Trade: 43.8600 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.9000 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 12:
# Timestamp: 2024-08-13 16:56:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.4364
# BSV Balance: 5610347.4556
# XAUT/BSV Price: 56.1038
# BSV Price Before Trade: 43.9000 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.9600 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 13:
# Timestamp: 2024-08-13 16:57:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.3362
# BSV Balance: 5610353.0775
# XAUT/BSV Price: 56.1039
# BSV Price Before Trade: 43.9600 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.8500 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 14:
# Timestamp: 2024-08-13 16:58:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.2358
# BSV Balance: 5610358.7136
# XAUT/BSV Price: 56.1040
# BSV Price Before Trade: 43.8500 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.9100 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 15:
# Timestamp: 2024-08-13 16:59:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.3358
# BSV Balance: 5610353.1032
# XAUT/BSV Price: 56.1039
# BSV Price Before Trade: 43.9100 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.9400 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.3525 USD
#
# Trade 16:
# Timestamp: 2024-08-13 17:00:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.2355
# BSV Balance: 5610358.7277
# XAUT/BSV Price: 56.1040
# BSV Price Before Trade: 43.9400 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.9600 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 17:
# Timestamp: 2024-08-13 17:01:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.1353
# BSV Balance: 5610364.3496
# XAUT/BSV Price: 56.1041
# BSV Price Before Trade: 43.9600 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.9500 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 18:
# Timestamp: 2024-08-13 17:02:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.2353
# BSV Balance: 5610358.7392
# XAUT/BSV Price: 56.1040
# BSV Price Before Trade: 43.9500 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.8500 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.5774 USD
#
# Trade 19:
# Timestamp: 2024-08-13 17:03:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.1349
# BSV Balance: 5610364.3752
# XAUT/BSV Price: 56.1041
# BSV Price Before Trade: 43.8500 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.7300 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 20:
# Timestamp: 2024-08-13 17:04:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.0341
# BSV Balance: 5610370.0267
# XAUT/BSV Price: 56.1042
# BSV Price Before Trade: 43.7300 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.9500 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 21:
# Timestamp: 2024-08-13 17:05:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.1341
# BSV Balance: 5610364.4163
# XAUT/BSV Price: 56.1041
# BSV Price Before Trade: 43.9500 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.8600 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.5779 USD
#
# Trade 22:
# Timestamp: 2024-08-13 17:06:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.0337
# BSV Balance: 5610370.0510
# XAUT/BSV Price: 56.1042
# BSV Price Before Trade: 43.8600 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.7800 USDT
# XAUT Price After Trade: 2471.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 23:
# Timestamp: 2024-08-13 17:07:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99998.9331
# BSV Balance: 5610375.6961
# XAUT/BSV Price: 56.1044
# BSV Price Before Trade: 43.7800 USDT
# XAUT Price Before Trade: 2471.4000 USDT
# BSV Price After Trade: 43.7300 USDT
# XAUT Price After Trade: 2467.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.1400 USD
#
# Trade 24:
# Timestamp: 2024-08-13 17:08:00
# Action: Sold 0.0700 XAUT
# XAUT Balance: 99999.0031
# BSV Balance: 5610371.7688
# XAUT/BSV Price: 56.1043
# BSV Price Before Trade: 43.7300 USDT
# XAUT Price Before Trade: 2467.4000 USDT
# BSV Price After Trade: 43.7800 USDT
# XAUT Price After Trade: 2467.4000 USDT
# Cost in BSV: 3.9273 BSV
# Cost in USD: 171.7409 USD
#
# Trade 25:
# Timestamp: 2024-08-13 17:09:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99998.9026
# BSV Balance: 5610377.4047
# XAUT/BSV Price: 56.1044
# BSV Price Before Trade: 43.7800 USDT
# XAUT Price Before Trade: 2467.4000 USDT
# BSV Price After Trade: 43.8900 USDT
# XAUT Price After Trade: 2467.4000 USDT
# Cost in BSV: 3.9273 BSV
# Cost in USD: 246.7400 USD
#
# Trade 26:
# Timestamp: 2024-08-13 17:10:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.0026
# BSV Balance: 5610371.7943
# XAUT/BSV Price: 56.1043
# BSV Price Before Trade: 43.8900 USDT
# XAUT Price Before Trade: 2467.4000 USDT
# BSV Price After Trade: 43.8800 USDT
# XAUT Price After Trade: 2467.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.2419 USD
#
# Trade 27:
# Timestamp: 2024-08-13 17:11:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99998.9024
# BSV Balance: 5610377.4173
# XAUT/BSV Price: 56.1044
# BSV Price Before Trade: 43.8800 USDT
# XAUT Price Before Trade: 2467.4000 USDT
# BSV Price After Trade: 43.9000 USDT
# XAUT Price After Trade: 2467.8000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.7400 USD
#
# Trade 28:
# Timestamp: 2024-08-13 17:12:00
# Action: Sold 0.1212 XAUT
# XAUT Balance: 99999.0236
# BSV Balance: 5610370.6162
# XAUT/BSV Price: 56.1043
# BSV Price Before Trade: 43.9000 USDT
# XAUT Price Before Trade: 2467.8000 USDT
# BSV Price After Trade: 43.9700 USDT
# XAUT Price After Trade: 2467.8000 USDT
# Cost in BSV: 6.8011 BSV
# Cost in USD: 298.5698 USD
#
# Trade 29:
# Timestamp: 2024-08-13 17:13:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99998.9236
# BSV Balance: 5610376.2286
# XAUT/BSV Price: 56.1044
# BSV Price Before Trade: 43.9700 USDT
# XAUT Price Before Trade: 2467.8000 USDT
# BSV Price After Trade: 43.9300 USDT
# XAUT Price After Trade: 2467.8000 USDT
# Cost in BSV: 6.8011 BSV
# Cost in USD: 246.7800 USD
#
# Trade 30:
# Timestamp: 2024-08-13 17:14:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.0236
# BSV Balance: 5610370.6182
# XAUT/BSV Price: 56.1043
# BSV Price Before Trade: 43.9300 USDT
# XAUT Price Before Trade: 2467.8000 USDT
# BSV Price After Trade: 43.9700 USDT
# XAUT Price After Trade: 2467.8000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.4662 USD
#
# Trade 31:
# Timestamp: 2024-08-13 17:15:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.1236
# BSV Balance: 5610365.0078
# XAUT/BSV Price: 56.1041
# BSV Price Before Trade: 43.9700 USDT
# XAUT Price Before Trade: 2467.8000 USDT
# BSV Price After Trade: 43.9800 USDT
# XAUT Price After Trade: 2467.8000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.6902 USD
#
# Trade 32:
# Timestamp: 2024-08-13 17:16:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99999.0236
# BSV Balance: 5610370.6190
# XAUT/BSV Price: 56.1043
# BSV Price Before Trade: 43.9800 USDT
# XAUT Price Before Trade: 2467.8000 USDT
# BSV Price After Trade: 43.8900 USDT
# XAUT Price After Trade: 2467.8000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.7800 USD
#
# Trade 33:
# Timestamp: 2024-08-13 17:17:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99998.9233
# BSV Balance: 5610376.2417
# XAUT/BSV Price: 56.1044
# BSV Price Before Trade: 43.8900 USDT
# XAUT Price Before Trade: 2467.8000 USDT
# BSV Price After Trade: 43.7700 USDT
# XAUT Price After Trade: 2467.8000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.7800 USD
#
# Trade 34:
# Timestamp: 2024-08-13 17:18:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.0233
# BSV Balance: 5610370.6312
# XAUT/BSV Price: 56.1043
# BSV Price Before Trade: 43.7700 USDT
# XAUT Price Before Trade: 2467.8000 USDT
# BSV Price After Trade: 43.8800 USDT
# XAUT Price After Trade: 2467.8000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 245.5686 USD
#
# Trade 35:
# Timestamp: 2024-08-13 17:19:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99998.9231
# BSV Balance: 5610376.2552
# XAUT/BSV Price: 56.1044
# BSV Price Before Trade: 43.8800 USDT
# XAUT Price Before Trade: 2467.8000 USDT
# BSV Price After Trade: 43.9000 USDT
# XAUT Price After Trade: 2467.8000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.7800 USD
#
# Trade 36:
# Timestamp: 2024-08-13 17:20:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.0231
# BSV Balance: 5610370.6448
# XAUT/BSV Price: 56.1043
# BSV Price Before Trade: 43.9000 USDT
# XAUT Price Before Trade: 2467.8000 USDT
# BSV Price After Trade: 44.0400 USDT
# XAUT Price After Trade: 2467.8000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.2979 USD
#
# Trade 37:
# Timestamp: 2024-08-13 17:21:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.1231
# BSV Balance: 5610365.0344
# XAUT/BSV Price: 56.1041
# BSV Price Before Trade: 44.0400 USDT
# XAUT Price Before Trade: 2467.8000 USDT
# BSV Price After Trade: 43.9800 USDT
# XAUT Price After Trade: 2470.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 247.0829 USD
#
# Trade 38:
# Timestamp: 2024-08-13 17:22:00
# Action: Sold 0.0040 XAUT
# XAUT Balance: 99999.1271
# BSV Balance: 5610364.8100
# XAUT/BSV Price: 56.1041
# BSV Price Before Trade: 43.9800 USDT
# XAUT Price Before Trade: 2470.4000 USDT
# BSV Price After Trade: 43.8300 USDT
# XAUT Price After Trade: 2470.4000 USDT
# Cost in BSV: 0.2244 BSV
# Cost in USD: 9.8698 USD
#
# Trade 39:
# Timestamp: 2024-08-13 17:23:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99999.2271
# BSV Balance: 5610359.1995
# XAUT/BSV Price: 56.1040
# BSV Price Before Trade: 43.8300 USDT
# XAUT Price Before Trade: 2470.4000 USDT
# BSV Price After Trade: 43.8000 USDT
# XAUT Price After Trade: 2465.7000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 245.9042 USD
#
# Trade 40:
# Timestamp: 2024-08-13 17:24:00
# Action: Bought 2.0224 XAUT
# XAUT Balance: 99997.1978
# BSV Balance: 5610473.0517
# XAUT/BSV Price: 56.1063
# BSV Price Before Trade: 43.8000 USDT
# XAUT Price Before Trade: 2465.7000 USDT
# BSV Price After Trade: 43.8900 USDT
# XAUT Price After Trade: 2465.7000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 4986.7254 USD
#
# Trade 41:
# Timestamp: 2024-08-13 17:25:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99997.0977
# BSV Balance: 5610478.6696
# XAUT/BSV Price: 56.1064
# BSV Price Before Trade: 43.8900 USDT
# XAUT Price Before Trade: 2465.7000 USDT
# BSV Price After Trade: 43.8600 USDT
# XAUT Price After Trade: 2465.4000 USDT
# Cost in BSV: 5.6104 BSV
# Cost in USD: 246.5700 USD
#
# Trade 42:
# Timestamp: 2024-08-13 17:26:00
# Action: Sold 0.0311 XAUT
# XAUT Balance: 99997.1289
# BSV Balance: 5610476.9220
# XAUT/BSV Price: 56.1064
# BSV Price Before Trade: 43.8600 USDT
# XAUT Price Before Trade: 2465.4000 USDT
# BSV Price After Trade: 43.8000 USDT
# XAUT Price After Trade: 2465.4000 USDT
# Cost in BSV: 1.7476 BSV
# Cost in USD: 76.6498 USD
#
# Trade 43:
# Timestamp: 2024-08-13 17:27:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99997.2289
# BSV Balance: 5610471.3114
# XAUT/BSV Price: 56.1063
# BSV Price Before Trade: 43.8000 USDT
# XAUT Price Before Trade: 2465.4000 USDT
# BSV Price After Trade: 43.8300 USDT
# XAUT Price After Trade: 2465.4000 USDT
# Cost in BSV: 5.6106 BSV
# Cost in USD: 245.7457 USD
#
# Trade 44:
# Timestamp: 2024-08-13 17:28:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99997.1286
# BSV Balance: 5610476.9363
# XAUT/BSV Price: 56.1064
# BSV Price Before Trade: 43.8300 USDT
# XAUT Price Before Trade: 2465.4000 USDT
# BSV Price After Trade: 43.8200 USDT
# XAUT Price After Trade: 2464.1000 USDT
# Cost in BSV: 5.6106 BSV
# Cost in USD: 246.5400 USD
#
# Trade 45:
# Timestamp: 2024-08-13 17:29:00
# Action: Bought 2.1556 XAUT
# XAUT Balance: 99994.9682
# BSV Balance: 5610598.1511
# XAUT/BSV Price: 56.1088
# BSV Price Before Trade: 43.8200 USDT
# XAUT Price Before Trade: 2464.1000 USDT
# BSV Price After Trade: 43.8300 USDT
# XAUT Price After Trade: 2464.1000 USDT
# Cost in BSV: 5.6106 BSV
# Cost in USD: 5311.6337 USD
#
# Trade 46:
# Timestamp: 2024-08-13 17:30:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.8680
# BSV Balance: 5610603.7731
# XAUT/BSV Price: 56.1089
# BSV Price Before Trade: 43.8300 USDT
# XAUT Price Before Trade: 2464.1000 USDT
# BSV Price After Trade: 43.8400 USDT
# XAUT Price After Trade: 2464.1000 USDT
# Cost in BSV: 5.6106 BSV
# Cost in USD: 246.4100 USD
#
# Trade 47:
# Timestamp: 2024-08-13 17:31:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.9680
# BSV Balance: 5610598.1622
# XAUT/BSV Price: 56.1088
# BSV Price Before Trade: 43.8400 USDT
# XAUT Price Before Trade: 2464.1000 USDT
# BSV Price After Trade: 43.9200 USDT
# XAUT Price After Trade: 2464.1000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 245.9812 USD
#
# Trade 48:
# Timestamp: 2024-08-13 17:32:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.8680
# BSV Balance: 5610603.7726
# XAUT/BSV Price: 56.1089
# BSV Price Before Trade: 43.9200 USDT
# XAUT Price Before Trade: 2464.1000 USDT
# BSV Price After Trade: 43.8800 USDT
# XAUT Price After Trade: 2463.7000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4100 USD
#
# Trade 49:
# Timestamp: 2024-08-13 17:33:00
# Action: Sold 0.1031 XAUT
# XAUT Balance: 99994.9711
# BSV Balance: 5610597.9861
# XAUT/BSV Price: 56.1088
# BSV Price Before Trade: 43.8800 USDT
# XAUT Price Before Trade: 2463.7000 USDT
# BSV Price After Trade: 43.8800 USDT
# XAUT Price After Trade: 2463.7000 USDT
# Cost in BSV: 5.7865 BSV
# Cost in USD: 253.9119 USD
#
# Trade 50:
# Timestamp: 2024-08-13 17:34:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99995.0711
# BSV Balance: 5610592.3752
# XAUT/BSV Price: 56.1087
# BSV Price Before Trade: 43.8800 USDT
# XAUT Price Before Trade: 2463.7000 USDT
# BSV Price After Trade: 43.8800 USDT
# XAUT Price After Trade: 2463.7000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.2052 USD
#
# Trade 51:
# Timestamp: 2024-08-13 17:35:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.9711
# BSV Balance: 5610597.9899
# XAUT/BSV Price: 56.1088
# BSV Price Before Trade: 43.8800 USDT
# XAUT Price Before Trade: 2463.7000 USDT
# BSV Price After Trade: 43.8400 USDT
# XAUT Price After Trade: 2463.7000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.3700 USD
#
# Trade 52:
# Timestamp: 2024-08-13 17:36:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99995.0711
# BSV Balance: 5610592.3790
# XAUT/BSV Price: 56.1087
# BSV Price Before Trade: 43.8400 USDT
# XAUT Price Before Trade: 2463.7000 USDT
# BSV Price After Trade: 43.8000 USDT
# XAUT Price After Trade: 2462.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 245.9807 USD
#
# Trade 53:
# Timestamp: 2024-08-13 17:37:00
# Action: Bought 0.0314 XAUT
# XAUT Balance: 99995.0396
# BSV Balance: 5610594.1433
# XAUT/BSV Price: 56.1087
# BSV Price Before Trade: 43.8000 USDT
# XAUT Price Before Trade: 2462.9000 USDT
# BSV Price After Trade: 43.8000 USDT
# XAUT Price After Trade: 2462.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 77.2760 USD
#
# Trade 54:
# Timestamp: 2024-08-13 17:38:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.9394
# BSV Balance: 5610599.7664
# XAUT/BSV Price: 56.1088
# BSV Price Before Trade: 43.8000 USDT
# XAUT Price Before Trade: 2462.9000 USDT
# BSV Price After Trade: 43.7900 USDT
# XAUT Price After Trade: 2462.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.2900 USD
#
# Trade 55:
# Timestamp: 2024-08-13 17:39:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.8392
# BSV Balance: 5610605.3907
# XAUT/BSV Price: 56.1089
# BSV Price Before Trade: 43.7900 USDT
# XAUT Price Before Trade: 2462.9000 USDT
# BSV Price After Trade: 43.8000 USDT
# XAUT Price After Trade: 2464.2000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.2900 USD
#
# Trade 56:
# Timestamp: 2024-08-13 17:40:00
# Action: Bought 0.4827 XAUT
# XAUT Balance: 99994.3552
# BSV Balance: 5610632.5466
# XAUT/BSV Price: 56.1095
# BSV Price Before Trade: 43.8000 USDT
# XAUT Price Before Trade: 2464.2000 USDT
# BSV Price After Trade: 43.8800 USDT
# XAUT Price After Trade: 2464.2000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 1189.4299 USD
#
# Trade 57:
# Timestamp: 2024-08-13 17:41:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.2551
# BSV Balance: 5610638.1624
# XAUT/BSV Price: 56.1096
# BSV Price Before Trade: 43.8800 USDT
# XAUT Price Before Trade: 2464.2000 USDT
# BSV Price After Trade: 43.8900 USDT
# XAUT Price After Trade: 2464.2000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4200 USD
#
# Trade 58:
# Timestamp: 2024-08-13 17:42:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.1550
# BSV Balance: 5610643.7769
# XAUT/BSV Price: 56.1097
# BSV Price Before Trade: 43.8900 USDT
# XAUT Price Before Trade: 2464.2000 USDT
# BSV Price After Trade: 44.0300 USDT
# XAUT Price After Trade: 2469.3000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4200 USD
#
# Trade 59:
# Timestamp: 2024-08-13 17:43:00
# Action: Bought 0.2623 XAUT
# XAUT Balance: 99993.8929
# BSV Balance: 5610658.4864
# XAUT/BSV Price: 56.1100
# BSV Price Before Trade: 44.0300 USDT
# XAUT Price Before Trade: 2469.3000 USDT
# BSV Price After Trade: 43.9600 USDT
# XAUT Price After Trade: 2469.3000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 647.6604 USD
#
# Trade 60:
# Timestamp: 2024-08-13 17:44:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99993.9929
# BSV Balance: 5610652.8754
# XAUT/BSV Price: 56.1099
# BSV Price Before Trade: 43.9600 USDT
# XAUT Price Before Trade: 2469.3000 USDT
# BSV Price After Trade: 44.0500 USDT
# XAUT Price After Trade: 2469.3000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.6594 USD
#
# Trade 61:
# Timestamp: 2024-08-13 17:45:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.0929
# BSV Balance: 5610647.2644
# XAUT/BSV Price: 56.1098
# BSV Price Before Trade: 44.0500 USDT
# XAUT Price Before Trade: 2469.3000 USDT
# BSV Price After Trade: 43.8900 USDT
# XAUT Price After Trade: 2469.3000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 247.1639 USD
#
# Trade 62:
# Timestamp: 2024-08-13 17:46:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.1929
# BSV Balance: 5610641.6535
# XAUT/BSV Price: 56.1097
# BSV Price Before Trade: 43.8900 USDT
# XAUT Price Before Trade: 2469.3000 USDT
# BSV Price After Trade: 43.9000 USDT
# XAUT Price After Trade: 2469.3000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.2656 USD
#
# Trade 63:
# Timestamp: 2024-08-13 17:47:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.2929
# BSV Balance: 5610636.0425
# XAUT/BSV Price: 56.1096
# BSV Price Before Trade: 43.9000 USDT
# XAUT Price Before Trade: 2469.3000 USDT
# BSV Price After Trade: 44.0100 USDT
# XAUT Price After Trade: 2469.3000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.3212 USD
#
# Trade 64:
# Timestamp: 2024-08-13 17:48:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.3929
# BSV Balance: 5610630.4315
# XAUT/BSV Price: 56.1095
# BSV Price Before Trade: 44.0100 USDT
# XAUT Price Before Trade: 2469.3000 USDT
# BSV Price After Trade: 43.9700 USDT
# XAUT Price After Trade: 2469.3000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.9379 USD
#
# Trade 65:
# Timestamp: 2024-08-13 17:49:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.4929
# BSV Balance: 5610624.8206
# XAUT/BSV Price: 56.1093
# BSV Price Before Trade: 43.9700 USDT
# XAUT Price Before Trade: 2469.3000 USDT
# BSV Price After Trade: 43.9300 USDT
# XAUT Price After Trade: 2469.3000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.7130 USD
#
# Trade 66:
# Timestamp: 2024-08-13 17:50:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.5929
# BSV Balance: 5610619.2097
# XAUT/BSV Price: 56.1092
# BSV Price Before Trade: 43.9300 USDT
# XAUT Price Before Trade: 2469.3000 USDT
# BSV Price After Trade: 43.8800 USDT
# XAUT Price After Trade: 2464.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4881 USD
#
# Trade 67:
# Timestamp: 2024-08-13 17:51:00
# Action: Bought 0.0383 XAUT
# XAUT Balance: 99994.5546
# BSV Balance: 5610621.3600
# XAUT/BSV Price: 56.1093
# BSV Price Before Trade: 43.8800 USDT
# XAUT Price Before Trade: 2464.8000 USDT
# BSV Price After Trade: 43.9300 USDT
# XAUT Price After Trade: 2464.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 94.3550 USD
#
# Trade 68:
# Timestamp: 2024-08-13 17:52:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.6546
# BSV Balance: 5610615.7491
# XAUT/BSV Price: 56.1092
# BSV Price Before Trade: 43.9300 USDT
# XAUT Price Before Trade: 2464.8000 USDT
# BSV Price After Trade: 43.9300 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4878 USD
#
# Trade 69:
# Timestamp: 2024-08-13 17:53:00
# Action: Bought 0.0085 XAUT
# XAUT Balance: 99994.6461
# BSV Balance: 5610616.2254
# XAUT/BSV Price: 56.1092
# BSV Price Before Trade: 43.9300 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 44.0000 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 20.9245 USD
#
# Trade 70:
# Timestamp: 2024-08-13 17:54:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.5462
# BSV Balance: 5610621.8274
# XAUT/BSV Price: 56.1093
# BSV Price Before Trade: 44.0000 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 44.0200 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4900 USD
#
# Trade 71:
# Timestamp: 2024-08-13 17:55:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.4464
# BSV Balance: 5610627.4269
# XAUT/BSV Price: 56.1094
# BSV Price Before Trade: 44.0200 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 44.0200 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4900 USD
#
# Trade 72:
# Timestamp: 2024-08-13 17:56:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.3466
# BSV Balance: 5610633.0264
# XAUT/BSV Price: 56.1095
# BSV Price Before Trade: 44.0200 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.9900 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4900 USD
#
# Trade 73:
# Timestamp: 2024-08-13 17:57:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.2468
# BSV Balance: 5610638.6297
# XAUT/BSV Price: 56.1096
# BSV Price Before Trade: 43.9900 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 44.0200 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4900 USD
#
# Trade 74:
# Timestamp: 2024-08-13 17:58:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.1470
# BSV Balance: 5610644.2292
# XAUT/BSV Price: 56.1097
# BSV Price Before Trade: 44.0200 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 44.1000 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4900 USD
#
# Trade 75:
# Timestamp: 2024-08-13 17:59:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.0474
# BSV Balance: 5610649.8186
# XAUT/BSV Price: 56.1098
# BSV Price Before Trade: 44.1000 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.9700 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4900 USD
#
# Trade 76:
# Timestamp: 2024-08-13 18:00:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99993.9475
# BSV Balance: 5610655.4244
# XAUT/BSV Price: 56.1100
# BSV Price Before Trade: 43.9700 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.9700 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4900 USD
#
# Trade 77:
# Timestamp: 2024-08-13 18:01:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99993.8476
# BSV Balance: 5610661.0303
# XAUT/BSV Price: 56.1101
# BSV Price Before Trade: 43.9700 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.9300 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.4900 USD
#
# Trade 78:
# Timestamp: 2024-08-13 18:02:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99993.9476
# BSV Balance: 5610655.4193
# XAUT/BSV Price: 56.1100
# BSV Price Before Trade: 43.9300 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.9000 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.4913 USD
#
# Trade 79:
# Timestamp: 2024-08-13 18:03:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.0476
# BSV Balance: 5610649.8083
# XAUT/BSV Price: 56.1098
# BSV Price Before Trade: 43.9000 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.8600 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.3224 USD
#
# Trade 80:
# Timestamp: 2024-08-13 18:04:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99993.9474
# BSV Balance: 5610655.4283
# XAUT/BSV Price: 56.1100
# BSV Price Before Trade: 43.8600 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.9200 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.4900 USD
#
# Trade 81:
# Timestamp: 2024-08-13 18:05:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.0474
# BSV Balance: 5610649.8173
# XAUT/BSV Price: 56.1098
# BSV Price Before Trade: 43.9200 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.9400 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.4347 USD
#
# Trade 82:
# Timestamp: 2024-08-13 18:06:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.1474
# BSV Balance: 5610644.2063
# XAUT/BSV Price: 56.1097
# BSV Price Before Trade: 43.9400 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.9500 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.5464 USD
#
# Trade 83:
# Timestamp: 2024-08-13 18:07:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.2474
# BSV Balance: 5610638.5953
# XAUT/BSV Price: 56.1096
# BSV Price Before Trade: 43.9500 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.8900 USDT
# XAUT Price After Trade: 2464.9000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.6020 USD
#
# Trade 84:
# Timestamp: 2024-08-13 18:08:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.3474
# BSV Balance: 5610632.9844
# XAUT/BSV Price: 56.1095
# BSV Price Before Trade: 43.8900 USDT
# XAUT Price Before Trade: 2464.9000 USDT
# BSV Price After Trade: 43.9100 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6110 BSV
# Cost in USD: 246.2648 USD
#
# Trade 85:
# Timestamp: 2024-08-13 18:09:00
# Action: Sold 0.0158 XAUT
# XAUT Balance: 99994.3632
# BSV Balance: 5610632.0958
# XAUT/BSV Price: 56.1095
# BSV Price Before Trade: 43.9100 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 43.9100 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 0.8885 BSV
# Cost in USD: 39.0162 USD
#
# Trade 86:
# Timestamp: 2024-08-13 18:10:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.4632
# BSV Balance: 5610626.4849
# XAUT/BSV Price: 56.1094
# BSV Price Before Trade: 43.9100 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0500 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.3765 USD
#
# Trade 87:
# Timestamp: 2024-08-13 18:11:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.5632
# BSV Balance: 5610620.8739
# XAUT/BSV Price: 56.1093
# BSV Price Before Trade: 44.0500 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0900 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 247.1615 USD
#
# Trade 88:
# Timestamp: 2024-08-13 18:12:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.6632
# BSV Balance: 5610615.2630
# XAUT/BSV Price: 56.1091
# BSV Price Before Trade: 44.0900 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0100 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 247.3855 USD
#
# Trade 89:
# Timestamp: 2024-08-13 18:13:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.5634
# BSV Balance: 5610620.8658
# XAUT/BSV Price: 56.1093
# BSV Price Before Trade: 44.0100 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0100 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.5800 USD
#
# Trade 90:
# Timestamp: 2024-08-13 18:14:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.6634
# BSV Balance: 5610615.2549
# XAUT/BSV Price: 56.1091
# BSV Price Before Trade: 44.0100 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0600 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.9366 USD
#
# Trade 91:
# Timestamp: 2024-08-13 18:15:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.7634
# BSV Balance: 5610609.6440
# XAUT/BSV Price: 56.1090
# BSV Price Before Trade: 44.0600 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0600 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 247.2167 USD
#
# Trade 92:
# Timestamp: 2024-08-13 18:16:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.6636
# BSV Balance: 5610615.2405
# XAUT/BSV Price: 56.1091
# BSV Price Before Trade: 44.0600 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0700 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.5800 USD
#
# Trade 93:
# Timestamp: 2024-08-13 18:17:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.7636
# BSV Balance: 5610609.6296
# XAUT/BSV Price: 56.1090
# BSV Price Before Trade: 44.0700 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0100 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 247.2728 USD
#
# Trade 94:
# Timestamp: 2024-08-13 18:18:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.6638
# BSV Balance: 5610615.2324
# XAUT/BSV Price: 56.1091
# BSV Price Before Trade: 44.0100 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0100 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.5800 USD
#
# Trade 95:
# Timestamp: 2024-08-13 18:19:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.7638
# BSV Balance: 5610609.6215
# XAUT/BSV Price: 56.1090
# BSV Price Before Trade: 44.0100 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0500 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.9361 USD
#
# Trade 96:
# Timestamp: 2024-08-13 18:20:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.8638
# BSV Balance: 5610604.0106
# XAUT/BSV Price: 56.1089
# BSV Price Before Trade: 44.0500 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0500 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 247.1600 USD
#
# Trade 97:
# Timestamp: 2024-08-13 18:21:00
# Action: Sold 0.1000 XAUT
# XAUT Balance: 99994.9638
# BSV Balance: 5610598.3997
# XAUT/BSV Price: 56.1088
# BSV Price Before Trade: 44.0500 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0500 USDT
# XAUT Price After Trade: 2465.8000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 247.1596 USD
#
# Trade 98:
# Timestamp: 2024-08-13 18:22:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.8640
# BSV Balance: 5610603.9974
# XAUT/BSV Price: 56.1089
# BSV Price Before Trade: 44.0500 USDT
# XAUT Price Before Trade: 2465.8000 USDT
# BSV Price After Trade: 44.0100 USDT
# XAUT Price After Trade: 2469.1000 USDT
# Cost in BSV: 5.6109 BSV
# Cost in USD: 246.5800 USD
#
# Trade 99:
# Timestamp: 2024-08-13 18:23:00
# Action: Sold 0.1839 XAUT
# XAUT Balance: 99995.0479
# BSV Balance: 5610593.6778
# XAUT/BSV Price: 56.1087
# BSV Price Before Trade: 44.0100 USDT
# XAUT Price Before Trade: 2469.1000 USDT
# BSV Price After Trade: 44.0100 USDT
# XAUT Price After Trade: 2469.1000 USDT
# Cost in BSV: 10.3196 BSV
# Cost in USD: 454.1652 USD
#
# Trade 100:
# Timestamp: 2024-08-13 18:24:00
# Action: Bought 0.1000 XAUT
# XAUT Balance: 99994.9479
# BSV Balance: 5610599.2881
# XAUT/BSV Price: 56.1088
# BSV Price Before Trade: 44.0100 USDT
# XAUT Price Before Trade: 2469.1000 USDT
# BSV Price After Trade: 44.0100 USDT
# XAUT Price After Trade: 2469.1000 USDT
# Cost in BSV: 10.3196 BSV
# Cost in USD: 246.9100 USD
#
# Trade Summary:
# Total number of trades: 100
# Total trade volume in BSV: 555.7056 BSV
# Total trade volume in USD: 34736.1327 USD
# Largest trade in USD: 5311.6337 USD
# Smallest trade in USD: 9.8698 USD
# Initial LP Positions:
# LP1 - XAUT: 60000.0600, BSV: 3366186.1362
# LP2 - XAUT: 30000.0300, BSV: 1683093.0681
# LP3 - XAUT: 10000.0100, BSV: 561031.0227
#
# LP Earnings and Final Positions After 100 Trades:
# LP1:
#   BSV Earned: 1.4150 BSV (~62.27 USDT)
#   Initial XAUT/BSV Ratio: 60000.0600 / 3366186.1362
#   Final XAUT/BSV Ratio: 59996.9688 / 3366359.5729
#   Total Earnings from Fees in USD: 62.27 USDT
#
# LP2:
#   BSV Earned: 0.7075 BSV (~31.14 USDT)
#   Initial XAUT/BSV Ratio: 30000.0300 / 1683093.0681
#   Final XAUT/BSV Ratio: 29998.4844 / 1683179.7864
#   Total Earnings from Fees in USD: 31.14 USDT
#
# LP3:
#   BSV Earned: 0.2358 BSV (~10.38 USDT)
#   Initial XAUT/BSV Ratio: 10000.0100 / 561031.0227
#   Final XAUT/BSV Ratio: 9999.4948 / 561059.9288
#   Total Earnings from Fees in USD: 10.38 USDT
#
# Total value of LPs' assets before 100 trades: 493820000.0002 USD
# Total value of LPs' assets after 100 trades: 493820000.6302 USD
